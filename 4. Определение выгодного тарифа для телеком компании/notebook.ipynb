# %% [markdown]
# # Описание проекта
#
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: Смарт и Ультра. Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег. Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
#
# Описание тарифов
#
# Тариф Смарт</font></b>:
#
# Ежемесячная плата: 550 рублей
# Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
# Стоимость услуг сверх тарифного пакета:
# минута разговора: 3 рубля
# сообщение: 3 рубля
# 1 Гб интернет-трафика: 200 рублей
# Тариф Ультра</font></b>:
#
# Ежемесячная плата: 1950 рублей
# Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# Стоимость услуг сверх тарифного пакета:
# минута разговора: 1 рубль
# сообщение: 1 рубль
# 1 Гб интернет-трафика: 150 рублей
# Обратите внимание: «Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута.

# %% [markdown]
# # Описание данных
#
# 1. Таблица users (информация о пользователях):
#
# user_id — уникальный идентификатор пользователя
# first_name — имя пользователя
# last_name — фамилия пользователя
# age — возраст пользователя (годы)
# reg_date — дата подключения тарифа (день, месяц, год)
# churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# city — город проживания пользователя
# tariff — название тарифного плана
#
# 2. Таблица calls (информация о звонках):
#
# id — уникальный номер звонка
# call_date — дата звонка
# duration — длительность звонка в минутах
# user_id — идентификатор пользователя, сделавшего звонок
#
# 3. Таблица messages (информация о сообщениях):
#
# id — уникальный номер сообщения
# message_date — дата сообщения
# user_id — идентификатор пользователя, отправившего сообщение
#
# 4. Таблица internet (информация об интернет-сессиях):
#
# id — уникальный номер сессии
# mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
# session_date — дата интернет-сессии
# user_id — идентификатор пользователя
#
# 5. Таблица tariffs (информация о тарифах):
#
# tariff_name — название тарифа
# rub_monthly_fee — ежемесячная абонентская плата в рублях
# minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
# messages_included — количество сообщений в месяц, включённых в абонентскую плату
# mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# rub_per_message — стоимость отправки сообщения сверх тарифного пакета
# rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# # Описание тарифов

# %% [markdown]
# **Тариф «Смарт»**
#
# Ежемесячная плата: 550 рублей
#
# Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
#
# Стоимость услуг сверх тарифного пакета: 1. минута разговора: 3 рубля («Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута); 2. сообщение: 3 рубля; 3. 1 Гб интернет-трафика: 200 рублей.
#
# **Тариф «Ультра»**
#
# Ежемесячная плата: 1950 рублей
#
# Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
#
# Стоимость услуг сверх тарифного пакета: 1. минута разговора: 1 рубль; 2. сообщение: 1 рубль; 3. 1 Гб интернет-трафика: 150 рублей.

# %% [markdown]
# # Задание

# %% [markdown]
#  **Шаг 1. Откройте файл с данными и изучите общую информацию**
# Путь к файлам:
# /datasets/calls.csv. Скачать датасет
# /datasets/internet.csv. Скачать датасет
# /datasets/messages.csv. Скачать датасет
# /datasets/tariffs.csv. Скачать датасет
# /datasets/users.csv. Скачать датасет
#
#  **Шаг 2. Подготовьте данные**
# Приведите данные к нужным типам;
# Найдите и исправьте ошибки в данных, если они есть.
# Поясните, какие ошибки вы нашли и как их исправили. В данных вы найдёте звонки с нулевой продолжительностью. Это не ошибка: нулями обозначены пропущенные звонки, поэтому их не нужно удалять.
# Посчитайте для каждого пользователя:
# количество сделанных звонков и израсходованных минут разговора по месяцам;
# количество отправленных сообщений по месяцам;
# объем израсходованного интернет-трафика по месяцам;
# помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).
#
#  **Шаг 3. Проанализируйте данные**
# Опишите поведение клиентов оператора, исходя из выборки. Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения.
#
#  **Шаг 4. Проверьте гипотезы**
# средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Пороговое значение alpha задайте самостоятельно.
# Поясните:
# как вы формулировали нулевую и альтернативную гипотезы;
# какой критерий использовали для проверки гипотез и почему.
#
#  **Шаг 5. Напишите общий вывод**
# Оформление: Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
users = pd.read_csv('/datasets/users.csv')
calls = pd.read_csv('/datasets/calls.csv')
messages = pd.read_csv('/datasets/messages.csv')
internet = pd.read_csv('/datasets/internet.csv')
tariffs = pd.read_csv('/datasets/tariffs.csv')

# %% [markdown]
# **Что сделал и выводы:**
# Загрузил библиотеки. Присвоил названия таблицам данных.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Исследование Users

# %%
print("Cтрок в датафрейме users:", users.shape[0])
print("Уникальных пользователей:", users['user_id'].count())
print("Дубликатов:", users.duplicated().sum())
# Out:
# Cтрок в датафрейме users: 500
# Уникальных пользователей: 500
# Дубликатов: 0

# %% [markdown]
# **Что сделал и выводы:**
# Посмотрел число строк в users. Число уникальных пользователей. Число дубликантов. Повторов нет, все пользователи уникальны.

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %% [markdown]
# **Что сделал и выводы:**
# Пропусков практически нет, за исключением churn_date - дата завершения пользования тарифом. Тут всё просто, скорее всего выгрузка происходила, когда тарифами ещё пользовались, поэтому в этом вопросе не трогаем.

# %% [markdown]
# ### Работа с датой и временем года

# %%
def get_season(date):
    if date.month in [1, 2, 12]:
        return 'зима'
    elif date.month in [3, 4, 5]:
        return 'весна'
    elif date.month in [6, 7, 8]:
        return 'лето'
    else:
        return 'осень'

def date_to_dt_month_season(dataframes):
    for df in dataframes:
        for column in df.columns:
            if 'date' in column and column != 'churn_date':
                df[column] = pd.to_datetime(df[column], format='%Y-%m-%d')
                df['месяц'] = df[column].apply(lambda x: x.month)
                df['время года'] = df[column].apply(get_season)

# %% [markdown]
# **Что сделал и выводы:**
# Прописал функцию определения времени года, зима, весна, лето и осень. Добавил столбцы месяц и время года дата фрэйм.

# %% [markdown]
# ### Работа с информацией о звонках

# %%
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# **Что сделал и выводы:**
# Колонки заполнены, тут всё хорошо.

# %%
plt.style.use('seaborn-pastel')

calls['duration'].plot(kind='hist', ec='black',figsize=(20,8), bins=50)

plt.xlabel("Длительность, сек.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Что сделал и выводы:**
# Большое кол-во вызовов с длительностью 0 секунд. Тут надо обратиться к заданию. "В данных вы найдёте звонки с нулевой продолжительностью. Это не ошибка: нулями обозначены пропущенные звонки, поэтому их не нужно удалять."

# %%
calls.query('0 < duration < 0.5')
# Out:
#               id   call_date  duration  user_id
# 55       1000_55  2018-09-19      0.31     1000
# 65       1000_65  2018-10-28      0.34     1000
# 97       1000_97  2018-10-26      0.33     1000
# 122     1000_122  2018-10-07      0.13     1000
# 135     1000_135  2018-10-25      0.02     1000
# ...          ...         ...       ...      ...
# 202318  1498_111  2018-10-17      0.46     1498
# 202322  1498_115  2018-10-02      0.49     1498
# 202438   1499_51  2018-10-08      0.47     1499
# 202452   1499_65  2018-11-30      0.20     1499
# 202484   1499_97  2018-12-22      0.07     1499
#
# [4074 rows x 4 columns]

# %% [markdown]
# **Что сделал и выводы:**
# В задании сказано, что звонки менее 1 секунды округляются в большую сторону, соответственно сделаю это.

# %%
calls['duration'] = calls['duration'].apply(np.ceil)
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25       0.0     1000
# 1  1000_1  2018-08-17       0.0     1000
# 2  1000_2  2018-06-11       3.0     1000
# 3  1000_3  2018-09-21      14.0     1000
# 4  1000_4  2018-12-15       6.0     1000

# %% [markdown]
# **Что сделал и выводы:**
# Округлил в большую сторону звонки, теперь проверю распределение на графике.

# %%
calls['duration'].plot(kind='hist', ec='black',figsize=(20,8), bins=50)
plt.xlabel("Длительность, сек.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Что сделал и выводы:**
# На графике видно, что значения адекватны. Стоит проверить нулевые звонки.

# %%
calls.query('duration == 0.0')
# Out:
#               id   call_date  duration  user_id
# 0         1000_0  2018-07-25       0.0     1000
# 1         1000_1  2018-08-17       0.0     1000
# 5         1000_5  2018-11-02       0.0     1000
# 6         1000_6  2018-10-18       0.0     1000
# 9         1000_9  2018-08-15       0.0     1000
# ...          ...         ...       ...      ...
# 202590  1499_203  2018-12-03       0.0     1499
# 202592  1499_205  2018-10-13       0.0     1499
# 202593  1499_206  2018-12-26       0.0     1499
# 202594  1499_207  2018-10-28       0.0     1499
# 202596  1499_209  2018-12-16       0.0     1499
#
# [39613 rows x 4 columns]

# %% [markdown]
# **Что сделал и выводы:**
# 39613 проверю, к одному ли тарифу они относятся. Может быть, на каком-то тарифе некорректно округлились данные, которые должны были округлиться в большую сторону.

# %%
map_to_fill_tariff = dict(pd.Series(users['tariff'].values, index=users['user_id']))
calls['Тариф'] = calls['user_id'].map(map_to_fill_tariff)
calls['Тариф'].value_counts()
# Out:
# smart    130315
# ultra     72292
# Name: Тариф, dtype: int64

# %% [markdown]
# **Что сделал и выводы:**
# Посмотрел распределение пользователей по тарифам. Смарт почти в 2 раза популярнее. По каждому из тарифов есть нулевые звонки. В задании сказано, что это несостоявшиеся звонки, поэтому т.к. они не расходуют лимиты минут и вообще не принимают участия в формировании конечной выручки можно их удалить.

# %%
#calls['duration'] = calls['duration'].replace(0, np.NaN)
#calls = calls.dropna()

# %%
calls['duration'].plot(kind='hist', ec='black', figsize=(20,8), bins=50)
plt.xlabel("Длительность, сек.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Что сделал и выводы:**
# Всё получилось. Итогом работы с информацией о звонках явилось округление в соответствии с заданием большую сторону. Данные подготовлены.

# %% [markdown]
# ### Работа с сообщениями

# %%
messages.head()
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# **Что сделал и выводы:**
# Посмотрел информацию по сообщениям. Всё довольно неплохо

# %% [markdown]
# ### Работа с информацией об интернет сессиях

# %%
internet.head()
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %% [markdown]
# **Что сделал и выводы:**
# Ещё раз обращаясь к заданию: «Мегалайн» всегда округляет вверх значения минут и мегабайт.
# Округляю в большую сторону до мегабайта весь трафик по каждой сессии.

# %%
#internet['mb_used'] = internet['mb_used'].apply(np.ceil)
internet.drop(columns = ['Unnamed: 0'],axis = 1,inplace=True)
internet.head()
# Out:
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000

# %%
internet['mb_used'].plot(kind='hist', ec='black', figsize=(20,8), bins=50)
plt.xlabel("Объем трафика, мб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %%
internet.query('mb_used == 0')
# Out:
#               id  mb_used session_date  user_id
# 11       1000_11      0.0   2018-08-28     1000
# 38       1000_38      0.0   2018-11-27     1000
# 46       1000_46      0.0   2018-06-30     1000
# 67       1000_67      0.0   2018-06-16     1000
# 72       1000_72      0.0   2018-06-15     1000
# ...          ...      ...          ...      ...
# 149380  1499_141      0.0   2018-12-11     1499
# 149381  1499_142      0.0   2018-11-01     1499
# 149383  1499_144      0.0   2018-11-27     1499
# 149386  1499_147      0.0   2018-10-21     1499
# 149393  1499_154      0.0   2018-10-27     1499
#
# [19598 rows x 4 columns]

# %% [markdown]
# **Что сделал и выводы:**
# Нулевых строк 19598, получается это сессии, когда подключение к интернету было включено, но в дальнейшем ни одной операции произведено не было. По примеру предыдущего задания исключаю их, т.к. не осуществляется потребление трафика.

# %%
internet['mb_used'] = internet['mb_used'].replace(0, np.NaN)
internet = internet.dropna()

# %% [markdown]
# **Что сделал и выводы:**
# Сделал округление, дропнул нулевые значения, чтобы не портили общую картину.

# %%
internet['mb_used'].plot(kind='hist', ec='black', figsize=(20,8), bins=50)
plt.xlabel("Объем трафика, мб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Что сделал и выводы:**
# Подготовил данные к работе. Осуществил округление до 1 мб. исключил нулевые данные из фрэйма.

# %% [markdown]
# ### Работа с тарифами

# %%
tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# **Что сделал и выводы:**
# Посмотрел как выглядят тарифы, тут всё неплохо. В изменении не нуждается.

# %% [markdown]
# ### Изменение типа данных столбцов, добавление новых в соответствии с месяцами и временами года

# %%
date_to_dt_month_season([users, calls, messages, internet])

# %%
users
# Out:
#      user_id  age  churn_date         city first_name  last_name   reg_date  \
# 0       1000   52         NaN    Краснодар     Рафаил  Верещагин 2018-05-25
# 1       1001   41         NaN       Москва       Иван       Ежов 2018-11-01
# 2       1002   59         NaN  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3       1003   23         NaN       Москва      Белла   Белякова 2018-08-17
# 4       1004   68         NaN  Новокузнецк    Татьяна   Авдеенко 2018-05-14
# ..       ...  ...         ...          ...        ...        ...        ...
# 495     1495   65         NaN      Иркутск  Авксентий      Фокин 2018-08-28
# 496     1496   36         NaN      Вологда     Трифон     Блохин 2018-01-27
# 497     1497   32         NaN    Челябинск   Каролина     Агеева 2018-10-09
# 498     1498   68  2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 499     1499   35         NaN        Пермь     Гектор   Корнилов 2018-09-27
#
#     tariff  месяц время года   Latitude   Longitude
# ...

# %%
calls
# Out:
#               id  call_date  duration  user_id  Тариф  месяц время года
# 0         1000_0 2018-07-25       0.0     1000  ultra      7       лето
# 1         1000_1 2018-08-17       0.0     1000  ultra      8       лето
# 2         1000_2 2018-06-11       3.0     1000  ultra      6       лето
# 3         1000_3 2018-09-21      14.0     1000  ultra      9      осень
# 4         1000_4 2018-12-15       6.0     1000  ultra     12       зима
# ...          ...        ...       ...      ...    ...    ...        ...
# 202602  1499_215 2018-12-26       1.0     1499  smart     12       зима
# 202603  1499_216 2018-10-18      19.0     1499  smart     10      осень
# 202604  1499_217 2018-11-10      11.0     1499  smart     11      осень
# 202605  1499_218 2018-10-06       5.0     1499  smart     10      осень
# 202606  1499_219 2018-12-14      20.0     1499  smart     12       зима
#
# [202607 rows x 7 columns]

# %%
messages
# Out:
#               id message_date  user_id  месяц время года
# 0         1000_0   2018-06-27     1000      6       лето
# 1         1000_1   2018-10-08     1000     10      осень
# 2         1000_2   2018-08-04     1000      8       лето
# 3         1000_3   2018-06-16     1000      6       лето
# 4         1000_4   2018-12-05     1000     12       зима
# ...          ...          ...      ...    ...        ...
# 123031  1499_179   2018-12-12     1499     12       зима
# 123032  1499_180   2018-09-28     1499      9      осень
# 123033  1499_181   2018-09-27     1499      9      осень
# 123034  1499_182   2018-11-15     1499     11      осень
# 123035  1499_183   2018-11-16     1499     11      осень
#
# [123036 rows x 5 columns]

# %%
internet.head()
# Out:
#        id  mb_used session_date  user_id  месяц время года
# 0  1000_0   112.95   2018-11-25     1000     11      осень
# 1  1000_1  1052.81   2018-09-07     1000      9      осень
# 2  1000_2  1197.26   2018-06-25     1000      6       лето
# 3  1000_3   550.27   2018-08-22     1000      8       лето
# 4  1000_4   302.56   2018-09-24     1000      9      осень

# %%
all_users = len(users)
df_for_barh = users.groupby('city').size()/all_users
df_for_barh_filtered = df_for_barh[df_for_barh > 0.015].sort_values()
ax = df_for_barh_filtered.plot(kind='barh', color='#03c03c', figsize=(15,10))

labels = dict(df_for_barh_filtered)
labels

i = 0
for city in labels:
    ax.text(labels[city] + 0.0005, i + 0.05, str(round(labels[city]*100, 2)) + '%', 
            fontsize = 'large', fontweight='bold', color='red')
    if i < 9.7:
        i += 0.98
    else:
        i += 1.02
ax.set_xlabel('% от общего числа')
ax.set_ylabel('Город')
# Out:
# Text(0, 0.5, 'Город')

# %% [markdown]
# **Что сделал и выводы:**
# Написал функцию распределения трафика по городам вывел в виде гистограмм в процентном соотношении. Больше всего пользователей в Москве и Санкт-Петербурге, что и логично.

# %% [markdown]
# ### Построение наглядной карты распределения трафика через геокод

# %%
list_of_cities = users['city'].unique().tolist()

# %% [markdown]
# **Что сделал и выводы:**
# Переписал уникальные названия городов в новый список.

# %%
import requests as r
url = 'https://geocode-maps.yandex.ru/1.x/?format=json&apikey=6b45ef9d-61c2-44f5-87fc-1c2807fde1bf&geocode='
coordinates = []

for city in list_of_cities:
    if city == city: # чтоб не столкнуться с nan
        url_formatted = url + city
        response = r.get(url_formatted).json()
        data = response['response']['GeoObjectCollection']['featureMember'][0]['GeoObject']['Point'].get('pos')
        coordinate = (float(data.split()[1]), float(data.split()[0]))
        coordinates.append(coordinate)
    else:
        coordinates.append('')

# %% [markdown]
# **Что сделал и выводы:**
# Замарочился и подключил функцию через геокод для отображения наглядной карты по распределению трафика, чуть дальше я её подгружу. Пока состыкую координаты с названием городов.

# %%
unique_cities_coordinates = pd.DataFrame({'Город':list_of_cities, 'Координаты':coordinates})
unique_cities_coordinates.head(10)
# Out:
#               Город              Координаты
# 0         Краснодар   (45.03547, 38.975313)
# 1            Москва   (55.75322, 37.622513)
# 2       Стерлитамак  (53.630403, 55.930825)
# 3       Новокузнецк  (53.757553, 87.136053)
# 4  Набережные Челны  (55.741272, 52.403662)
# 5         Ульяновск  (54.314192, 48.403132)
# 6         Челябинск  (55.159902, 61.402554)
# 7             Пермь  (58.010455, 56.229443)
# 8            Тюмень  (57.152985, 65.541227)
# 9            Самара  (53.195878, 50.100202)

# %% [markdown]
# **Что сделал и выводы:**
# Сопоставил координаты городов с их названиями.

# %%
dict_unique_cities_coordinates = dict(pd.Series(unique_cities_coordinates['Координаты'].values,
                                index=unique_cities_coordinates['Город'].values))

# %%
users['coordinates'] = users['city'].map(dict_unique_cities_coordinates)

# %% [markdown]
# **Что сделал и выводы:**
# Сформировал словарь с координатами, чтобы доваить в users, далее разнесу долготу и широту в разные столбцы и уберу начальный столбец с координатами.

# %%
users['Latitude'] = users['coordinates'].apply(lambda x: x[0])
users['Longitude'] = users['coordinates'].apply(lambda x: x[1])
users = users.drop(['coordinates'], axis=1)

# %% [markdown]
# **Что сделал и выводы:**
# Создал новые столбцы в таблице с долготой и широтой, чтобы можно было обращаться к данным для построения карты.

# %%
users.head(10)
# Out:
#    user_id  age churn_date              city first_name  last_name   reg_date  \
# 0     1000   52        NaN         Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaN            Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaN       Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaN            Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaN       Новокузнецк    Татьяна   Авдеенко 2018-05-14
# 5     1005   67        NaN  Набережные Челны   Афанасий     Горлов 2018-01-25
# 6     1006   21        NaN         Ульяновск     Леонид   Ермолаев 2018-02-26
# 7     1007   65        NaN            Москва        Юна   Березина 2018-04-19
# 8     1008   63        NaN         Челябинск     Рустэм  Пономарёв 2018-12-19
# 9     1009   24        NaN             Пермь   Василиса    Блинова 2018-03-22
#
#   tariff  месяц время года   Latitude  Longitude
# 0  ultra      5      весна  45.035470  38.975313
# ...

# %% [markdown]
# **Что сделал и выводы:**
# Всё получилось довольно неплохо, теперь визуализирую через фолим.

# %%
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 95 kB 1.0 MB/s eta 0:00:01
# ...

# %% [markdown]
# **Что сделал и выводы:**
# Подключил библиотку визуализации на карте "Фолиум"

# %%
users_folium = users.copy()

# %%
users_folium
# Out:
#      user_id  age  churn_date         city first_name  last_name   reg_date  \
# 0       1000   52         NaN    Краснодар     Рафаил  Верещагин 2018-05-25
# 1       1001   41         NaN       Москва       Иван       Ежов 2018-11-01
# 2       1002   59         NaN  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3       1003   23         NaN       Москва      Белла   Белякова 2018-08-17
# 4       1004   68         NaN  Новокузнецк    Татьяна   Авдеенко 2018-05-14
# ..       ...  ...         ...          ...        ...        ...        ...
# 495     1495   65         NaN      Иркутск  Авксентий      Фокин 2018-08-28
# 496     1496   36         NaN      Вологда     Трифон     Блохин 2018-01-27
# 497     1497   32         NaN    Челябинск   Каролина     Агеева 2018-10-09
# 498     1498   68  2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 499     1499   35         NaN        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %% [markdown]
# **Что сделал и выводы:**
# Создал отдельный датафрейм, на основе которого будет рисоваться карта. Folium при прорисовке HeatMap имеет не учитывает количество повторений в датафрейме каждой точки. В итоге получается так, что, например, 100 точек в Москве и 10 точек в Ростове имеют одинаковую интенсивность.
# Поэтому обойду это через добавление к широте и к долготе нескольких сотых, чтобы каждая точка прорисовывалась отдельно, но в рамках необходимого города.
# Некоторые точки могут оказаться в лесу или в воде, но это будет видно только при приближении, на общем плане всё будет в рамках территории/области города. В общем и целом я считаю это довольно таки неплохо, потому что на уроках такого не было. Решил сам подзаморочиться и сделать красиво. Надеюсь на + в карму)

# %%
import random

def new_lat(row):
    rand_number = random.uniform(-1,1)/5
    return row['Latitude'] + rand_number

def new_long(row):
    rand_number = random.uniform(-1,1)/5
    return row['Longitude'] + rand_number

# %%
users_folium['New_Lat'] = users_folium.apply(new_lat, axis=1)
users_folium['New_Long'] = users_folium.apply(new_long, axis=1)
users_folium['count'] = 1

# %% [markdown]
# **Что сделал и выводы:**
# Создал столбцы с расширенными данными по широте и долготе. Добавил ещё столбец count, чтобы образовать единичные веса для построения HeatMap. Далее импортирую Folium и рисую карту.

# %%
import folium
from folium.plugins import HeatMap

base_map = folium.Map(location=[56.838011, 60.597465], control_scale=False, zoom_start=3)

data = users_folium[['New_Lat', 'New_Long', 'count']].groupby(['New_Lat', 'New_Long']).sum().reset_index().values.tolist()
HeatMap(data=data, radius=10, max_zoom=5, gradient={.4: 'blue', .8: 'lime', 1.0: 'red'},
        blur=10, max_val=15).add_to(base_map)

base_map
# Out:
# /tmp/ipykernel_53/1455288545.py:7: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   HeatMap(data=data, radius=10, max_zoom=5, gradient={.4: 'blue', .8: 'lime', 1.0: 'red'},
# ...

# %%
users_folium.to_csv('d:\out_heatmap_ya.csv')

# %% [markdown]
# **Что сделал и выводы:**
# Всё получилось и выглядит класно и самое главное наглядно.

# %% [markdown]
# ### Проверка наиболее распространенного способа связи

# %%
def barplot_by_month(dfs, query=None):
    list_of_dfs = dfs
    plt.figure(figsize=(15,5))
    ax = plt.gca()
    
    list_of_colors = ['forestgreen', 'grey', 'mediumaquamarine']

    dfs_names_for_legend = ['Кол-во звонков', 'Кол-во отпр. СМС', 'Кол-во интернет-сессий']
    legend_list = []

    for i in range(len(list_of_dfs)):
        curr_df = list_of_dfs[i]
        if query == None:
            curr_df_prepared = curr_df.groupby('месяц')['id'].count().reset_index()
        else:
            curr_df_prepared = curr_df.query(query).groupby('месяц')['id'].count().reset_index()
        plot = curr_df_prepared.plot(x='месяц', y='id', kind='bar', ec='black', color=list_of_colors[i],
                                 ax=ax, width=0.1, position=i)
        legend_list.append(dfs_names_for_legend[i])
    plt.xticks(rotation=0)
    ax.legend(legend_list)

# %%
barplot_by_month([calls, messages, internet])

# %% [markdown]
# **Выводы:**
# 1. Чаще всего абоненты совершают звонки, реже всего отправляют СМС.
# 2. Выглядит таким образом, как будто оператор начинает свою работу и дальше наращивает число пользователей. Для проверки гипотезы беру случайного пользователя и посмотрю на его примере.

# %%
barplot_by_month([calls, messages, internet], query='user_id == 1100')

# %% [markdown]
# **Что сделал и выводы:**
# Теория пподтвердилась. Скорее всего осуществляется работа с данными за первый год.

# %% [markdown]
# ### Расчёт помесячной выручки

# %% [markdown]
# Что сделаю для каждого пользователя:
#
# 1. Рассчитаю количество сделанных звонков и израсходованных минут разговора по месяцам;
# 2. Рассчитаю количество отправленных сообщений по месяцам;
# 3. Рассчитаю объем израсходованного интернет-трафика по месяцам;
# 4. Рассчитаю помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).

# %%
num_of_calls = calls.groupby(['user_id', 'время года', 'месяц'])['duration'].agg(['count', 'sum'])
num_of_messages = messages.groupby(['user_id', 'время года', 'месяц'])['id'].count()
num_of_internet = internet.groupby(['user_id', 'время года', 'месяц']).sum()['mb_used']

# %%
df_event_numbers = pd.concat([num_of_calls, num_of_messages, num_of_internet], axis=1)
df_event_numbers = df_event_numbers.reset_index()
df_event_numbers.head()
# Out:
#    user_id время года  месяц  count    sum    id   mb_used
# 0     1000      весна      5   22.0  159.0  22.0   2253.49
# 1     1000       зима     12   46.0  333.0  70.0   9817.61
# 2     1000       лето      6   43.0  172.0  60.0  23233.77
# 3     1000       лето      7   47.0  340.0  75.0  14003.64
# 4     1000       лето      8   52.0  408.0  81.0  14055.93

# %% [markdown]
# **Что сделано:**
# Для начала взял из каждого имеющегося датафрейма нужную информацию и 'склеил' эти данные в один датафрейм df_event_numbers.

# %%
map_to_fill_tariff = dict(pd.Series(users['tariff'].values, index=users['user_id']))
df_event_numbers['Тариф'] = df_event_numbers['user_id'].map(map_to_fill_tariff)

map_to_fill_city = dict(pd.Series(users['city'].values, index=users['user_id']))
df_event_numbers['Город'] = df_event_numbers['user_id'].map(map_to_fill_city)

map_to_fill_Latitude = dict(pd.Series(users['Latitude'].values, index=users['user_id']))
df_event_numbers['Latitude'] = df_event_numbers['user_id'].map(map_to_fill_Latitude)

map_to_fill_Longitude = dict(pd.Series(users['Longitude'].values, index=users['user_id']))
df_event_numbers['Longitude'] = df_event_numbers['user_id'].map(map_to_fill_Longitude)

# %%
df_event_numbers.columns = ['User_id', 'Время года', 'Месяц', 'Кол-во звонков, шт.', 'Звонки, мин.', 
                            'СМС, шт.', 'Интернет, Мб', 'Тариф', 'Город', 'Широта', 'Долгота']

# %%
df_event_numbers.sort_values(by=['User_id', 'Месяц']).head(10)
# Out:
#    User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0     1000      весна      5                 22.0         159.0      22.0
# 2     1000       лето      6                 43.0         172.0      60.0
# 3     1000       лето      7                 47.0         340.0      75.0
# 4     1000       лето      8                 52.0         408.0      81.0
# 5     1000      осень      9                 58.0         466.0      57.0
# 6     1000      осень     10                 57.0         350.0      73.0
# 7     1000      осень     11                 43.0         338.0      58.0
# 1     1000       зима     12                 46.0         333.0      70.0
# 9     1001      осень     11                 59.0         430.0       NaN
# 8     1001       зима     12                 63.0         414.0       NaN
#
#    Интернет, Мб  Тариф      Город    Широта    Долгота
# 0       2253.49  ultra  Краснодар  45.03547  38.975313
# ...

# %% [markdown]
# **Что сделано:**
# Добавил столбцы с тарифом, городом, широтой и долготой, переименовал столбцы.Изменения выполнены верно.

# %%
df_event_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_id              3214 non-null   int64
#  1   Время года           3214 non-null   object
#  2   Месяц                3214 non-null   int64
#  3   Кол-во звонков, шт.  3174 non-null   float64
#  4   Звонки, мин.         3174 non-null   float64
#  5   СМС, шт.             2717 non-null   float64
#  6   Интернет, Мб         3201 non-null   float64
#  7   Тариф                3214 non-null   object
#  8   Город                3214 non-null   object
#  9   Широта               3214 non-null   float64
#  10  Долгота              3214 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 276.3+ KB

# %%
df_event_numbers[df_event_numbers['Интернет, Мб'].isnull()]
# Out:
#       User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 592      1094      весна      5                 16.0         107.0       3.0
# 1722     1273      весна      5                 24.0         220.0      21.0
# 1723     1273       зима     12                 41.0         260.0      39.0
# 1724     1273       лето      6                 40.0         230.0      38.0
# 1725     1273       лето      7                 44.0         253.0      37.0
# 1726     1273       лето      8                 53.0         253.0      41.0
# 1727     1273      осень      9                 33.0         223.0      32.0
# 1728     1273      осень     10                 40.0         315.0      35.0
# 1729     1273      осень     11                 45.0         272.0      29.0
# 2307     1365      осень     10                  5.0          43.0       1.0
# 2390     1377       зима      2                 23.0         179.0       2.0
# ...

# %% [markdown]
# **Выводы:** Много пропусков в каждом из столбцов, скорее всегонекоторые из пользователей за рассматриваемый период времени или ни разу не звонили, или ни разу не отправляли СМС, или ни разу не выходили в интернет. Посмотрю, нет ли в дата фрейме пользователей, которые ни разу не звонили, не отправляли смс и не заходили в интернет:

# %%
df_event_numbers[(df_event_numbers['Интернет, Мб'].isnull()) & (df_event_numbers['СМС, шт.'].isnull()) &
                 (df_event_numbers['Звонки, мин.'].isnull())]
# Out:
# Empty DataFrame
# Columns: [User_id, Время года, Месяц, Кол-во звонков, шт., Звонки, мин., СМС, шт., Интернет, Мб, Тариф, Город, Широта, Долгота]
# Index: []

# %% [markdown]
# **Выводы:** Пропусков нет, значит каждый из пользователей активный, просто в какие-то периоды мог не пользоваться каким либо типом связи.
#
# Ставлю по имеющимся пропускам нули, которые будут означать, что в конкретном месяце данный клиент не звонил/не отправлял СМС/не пользовался интернетом:

# %%
df_event_numbers = df_event_numbers.fillna(0)

# %%
df_event_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_id              3214 non-null   int64
#  1   Время года           3214 non-null   object
#  2   Месяц                3214 non-null   int64
#  3   Кол-во звонков, шт.  3214 non-null   float64
#  4   Звонки, мин.         3214 non-null   float64
#  5   СМС, шт.             3214 non-null   float64
#  6   Интернет, Мб         3214 non-null   float64
#  7   Тариф                3214 non-null   object
#  8   Город                3214 non-null   object
#  9   Широта               3214 non-null   float64
#  10  Долгота              3214 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 276.3+ KB

# %%
all_users = df_event_numbers['User_id'].count()


def func_pct(pct):
    value = float(pct/100.*all_users)
    return "{:.2f}%\n({:.0f} чел.)".format(pct, value)

explode = (0.1, 0)

axes = df_event_numbers.groupby('Тариф')['User_id'].count().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = 'Распределение по клиентам', pctdistance=0.5,
                                                                     figsize=(5,5), autopct=lambda pct: func_pct(pct))

plt.tight_layout(pad=0)

for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.88,0.88), prop={'size':15})
    ax.set_ylabel('')

# %% [markdown]
# **Что сделано/ выводы:** Уже выводил эти данные и раньше, но теперь наглядно видно что почти 70% пользователей в тарифе смарт.
# Дальше посмотрю распределениее звонков, смс и интернета по тарифам.

# %%
columns_to_plot = ['Звонки, мин.', 'СМС, шт.', 'Интернет, Мб']

calls_sum = df_event_numbers['Звонки, мин.'].sum()
sms_sum = df_event_numbers['СМС, шт.'].sum()
internet_sum = df_event_numbers['Интернет, Мб'].sum()

def func_pct(pct):
    if pct > 65 or pct < 35:
        sum_of_data = internet_sum
        value = float(pct/100.*sum_of_data/1024)
        metric = 'Гб'
    elif pct > 64 or pct < 36:
        sum_of_data = calls_sum
        value = float(pct/100.*sum_of_data)
        metric = 'мин.'
    else:
        sum_of_data = sms_sum
        value = float(pct/100.*sum_of_data)
        metric = 'шт.'
    return "{:.2f}%\n({:.0f} {})".format(pct, value, metric)

explode = (0.1, 0)

axes = df_event_numbers.groupby('Тариф')[columns_to_plot].sum().plot(kind='pie', subplots=True, fontsize=17,
                                                                       use_index=False, shadow=True, explode=explode,
                                                                       title = columns_to_plot, pctdistance=0.45,
                                                                       autopct=lambda pct: func_pct(pct), figsize=(20,5))

for ax in axes:
    ax.legend(['Смарт', 'Ультра'], framealpha=0.2, bbox_to_anchor=(0.88,0.88), prop={'size':15})
    ax.set_ylabel('')

# %% [markdown]
# **Выводы:** Как говорится что и требовалось доказать. От 60 до 65 % звонков, смс и интернета проходит в тарифе smart.

# %%
month_price = {'smart': 550, 'ultra': 1950}
df_event_numbers['Аб. плата, руб.'] = df_event_numbers['Тариф'].map(month_price)

# %% [markdown]
# **Что сделал:** Буду создавать новый столбец с абонентской платой в соответсвии с заданием.

# %%
df_event_numbers.head()
# Out:
#    User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0     1000      весна      5                 22.0         159.0      22.0
# 1     1000       зима     12                 46.0         333.0      70.0
# 2     1000       лето      6                 43.0         172.0      60.0
# 3     1000       лето      7                 47.0         340.0      75.0
# 4     1000       лето      8                 52.0         408.0      81.0
#
#    Интернет, Мб  Тариф      Город    Широта    Долгота  Аб. плата, руб.
# 0       2253.49  ultra  Краснодар  45.03547  38.975313             1950
# 1       9817.61  ultra  Краснодар  45.03547  38.975313             1950
# 2      23233.77  ultra  Краснодар  45.03547  38.975313             1950
# 3      14003.64  ultra  Краснодар  45.03547  38.975313             1950
# 4      14055.93  ultra  Краснодар  45.03547  38.975313             1950

# %%
def calls_over_plan(row):
    if row['Тариф'] == 'smart':
        result = row['Звонки, мин.'] - 500
        return np.where(result > 0, result, 0)
    else:
        result = row['Звонки, мин.'] - 3000
        return np.where(result > 0, result, 0)
    
    
def sms_over_plan(row):
    if row['Тариф'] == 'smart':
        result = row['СМС, шт.'] - 50
        return np.where(result > 0, result, 0)
    else:
        result =  row['СМС, шт.'] - 1000
        return np.where(result > 0, result, 0)
    
def internet_over_plan(row):
    if row['Тариф'] == 'smart':
        result = row['Интернет, Мб'] - 15 * 1024
        return np.where(result > 0, result, 0)
    else:
        result = row['Интернет, Мб'] - 30 * 1024
        return np.where(result > 0, result, 0)
    
def internet_over_plan_gb(row):
    if row['Тариф'] == 'smart':
        result = row['Интернет, Гб'] - 15
        return np.where(result > 0, result, 0)
    else:
        result = row['Интернет, Гб'] - 30
        return np.where(result > 0, result, 0)
    
    
def month_revenue(row):
    sum_per_month = 0
    if row['Тариф'] == 'smart':
        # sum_per_month += np.ceil(row['Минуты сверх']) * 3
        sum_per_month += row['Минуты сверх'] * 3
        sum_per_month += row['СМС сверх'] * 3
        # sum_per_month += np.ceil(row['Мб сверх']/1024) * 200
        sum_per_month += row['Гб сверх'] * 200
        return sum_per_month
    
    else:
        # sum_per_month += np.ceil(row['Минуты сверх']) * 1
        sum_per_month += row['Минуты сверх'] * 1
        sum_per_month += row['СМС сверх'] * 1
        # sum_per_month += np.ceil(row['Мб сверх']/1024) * 150
        sum_per_month += row['Гб сверх'] * 150
        return sum_per_month

# %%
df_event_numbers.head()
# Out:
#    User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0     1000      весна      5                 22.0         159.0      22.0
# 1     1000       зима     12                 46.0         333.0      70.0
# 2     1000       лето      6                 43.0         172.0      60.0
# 3     1000       лето      7                 47.0         340.0      75.0
# 4     1000       лето      8                 52.0         408.0      81.0
#
#    Интернет, Мб  Тариф      Город    Широта    Долгота  Аб. плата, руб.
# 0       2253.49  ultra  Краснодар  45.03547  38.975313             1950
# 1       9817.61  ultra  Краснодар  45.03547  38.975313             1950
# 2      23233.77  ultra  Краснодар  45.03547  38.975313             1950
# 3      14003.64  ultra  Краснодар  45.03547  38.975313             1950
# 4      14055.93  ultra  Краснодар  45.03547  38.975313             1950

# %%
df_event_numbers['Интернет, Гб'] = np.ceil(df_event_numbers['Интернет, Мб'] / 1024)

df_event_numbers['Минуты сверх'] = df_event_numbers.apply(calls_over_plan, axis=1)
df_event_numbers['СМС сверх'] = df_event_numbers.apply(sms_over_plan, axis=1)
df_event_numbers['Мб сверх'] = df_event_numbers.apply(internet_over_plan, axis=1)
df_event_numbers['Гб сверх'] = df_event_numbers.apply(internet_over_plan_gb, axis=1)

df_event_numbers['Плата сверх лимита, руб.'] = df_event_numbers.apply(month_revenue, axis=1)

for column in ['Минуты сверх', 'Мб сверх']:
    df_event_numbers[column] = df_event_numbers[column].astype('float')

for column in ['СМС сверх', 'Плата сверх лимита, руб.']:
    df_event_numbers[column] = df_event_numbers[column].astype('int')

# %%
df_event_numbers.head(20)
# Out:
#     User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0      1000      весна      5                 22.0         159.0      22.0
# 1      1000       зима     12                 46.0         333.0      70.0
# 2      1000       лето      6                 43.0         172.0      60.0
# 3      1000       лето      7                 47.0         340.0      75.0
# 4      1000       лето      8                 52.0         408.0      81.0
# 5      1000      осень      9                 58.0         466.0      57.0
# 6      1000      осень     10                 57.0         350.0      73.0
# 7      1000      осень     11                 43.0         338.0      58.0
# 8      1001       зима     12                 63.0         414.0       0.0
# 9      1001      осень     11                 59.0         430.0       0.0
# 10     1002       зима     12                 33.0         236.0      12.0
# ...

# %% [markdown]
# **Что сделал:** Написал функцию, которая считает Минуты сверх, СМС сверх, Мб сверх, Плата сверх лимита. Написал функцию, которая считает превышения в зависимости от тарифа.

# %%
df_event_numbers['Сумма за месяц, руб.'] = df_event_numbers['Аб. плата, руб.'] + df_event_numbers['Плата сверх лимита, руб.']

# %% [markdown]
# **Что сделал:** Создал столбец Сумма за месяц построчно просуммировав данные по 2 столбцам: "Аб. плата" и "Плата сверх лимита"

# %%
df_event_numbers.head(10)
# Out:
#    User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0     1000      весна      5                 22.0         159.0      22.0
# 1     1000       зима     12                 46.0         333.0      70.0
# 2     1000       лето      6                 43.0         172.0      60.0
# 3     1000       лето      7                 47.0         340.0      75.0
# 4     1000       лето      8                 52.0         408.0      81.0
# 5     1000      осень      9                 58.0         466.0      57.0
# 6     1000      осень     10                 57.0         350.0      73.0
# 7     1000      осень     11                 43.0         338.0      58.0
# 8     1001       зима     12                 63.0         414.0       0.0
# 9     1001      осень     11                 59.0         430.0       0.0
#
#    Интернет, Мб  Тариф      Город    Широта    Долгота  Аб. плата, руб.  \
# 0       2253.49  ultra  Краснодар  45.03547  38.975313             1950
# ...

# %%
df_event_numbers[df_event_numbers['Сумма за месяц, руб.'] > 1950]
# Out:
#       User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 68       1009       лето      7                 22.0         183.0      14.0
# 69       1009       лето      8                 33.0         249.0       9.0
# 81       1011       зима     12                 58.0         361.0       6.0
# 87       1011      осень     11                 65.0         501.0      12.0
# 90       1012      весна      5                 43.0         316.0      10.0
# ...       ...        ...    ...                  ...           ...       ...
# 3199     1496       лето      8                 88.0         527.0      41.0
# 3200     1496      осень      9                 68.0         486.0      29.0
# 3201     1496      осень     10                 72.0         450.0      35.0
# 3202     1496      осень     11                 80.0         662.0      46.0
# 3207     1498       лето      8                 57.0         400.0      62.0
#
# ...

# %% [markdown]
# **Что сделал:** Проверил, есть ли пользователи, которые выходят за рамки лимитов по тарифу. Такие есть. Соответственно для доп. расчётов создам столбец с теми, кому не хватило тарифного плана.

# %%
df_event_numbers['Не хватило тарифного плана'] = np.where(df_event_numbers['Плата сверх лимита, руб.'] > 0, 1, 0)

# %% [markdown]
# **Что сделал:** Создал столбец с теми, кому не хватило тарифного плана. Признак 0 - тариф не привышен, 1 - превышен.

# %%
filter_list = ['smart', 'ultra']
titles_list = ['По клиентам тарифа "Смарт"', 'По клиентам тарифа "Ультра"']
rows = 1
cols = 2
filter_list_counter = 0

sum_smart = df_event_numbers[df_event_numbers['Тариф'] == 'smart'].count()['User_id']
sum_ultra = df_event_numbers[df_event_numbers['Тариф'] == 'ultra'].count()['User_id']

annot_labels = ['В рамках тарифа', 'Дозаказ услуг']

def func_pct(pct):
    if pct < 75 and pct > 25:
        value = float(pct/100.*sum_smart)
    else:
        value = float(pct/100.*sum_ultra)
    return "{:.2f}%\n({:.0f} чел.)".format(pct, value)

fig, axes = plt.subplots(rows, cols, figsize=(20,10))

explode = (0.1, 0)

for r in range(rows):
    for c in range(cols):
        if filter_list[filter_list_counter] == 'smart':
            colors = ['#2d6fee', '#2dcfee']
        else:
            colors = ['#2dcfee', '#2d6fee']
        curr_filtered_df = df_event_numbers[df_event_numbers['Тариф'] == filter_list[filter_list_counter]].groupby('Не хватило тарифного плана')['User_id']
        ax = curr_filtered_df.count().plot(kind='pie', fontsize=14, use_index=False, shadow=True, explode=explode,
                                           title=titles_list[filter_list_counter], pctdistance=0.55, figsize=(20,5),
                                           autopct=lambda pct: func_pct(pct), startangle=200, ax=axes[c], colors=colors,
                                           labels=None)

        filter_list_counter += 1

plt.tight_layout(pad=3)

for ax in axes:
    ax.legend(['В рамках тарифа', 'Дозаказ услуг'], bbox_to_anchor=(0.88,0.85), prop={'size':15})
    ax.set_ylabel('')
    ax.title.set_size(16)
    ax.title.set_position([0.5, 1.15])

# %% [markdown]
# **Что сделал:** Создал круговую диаграмму с пользователями, которые дозаказывают услуги в рамках тарифного плана.
# Видно, что по тарифу Smart почти в  75 % случаев клиентам не хватает заложенных в абонентскую плату минут, СМС или гигабайт, и они дозаказывают эти услуги. И наоборот, почти всем клиентам с тарифом Ультра всегда всего хватает, кроме почти 14% - они тоже дозаказывают услуги вне поверх абонентской платы.
#
# Посмотрю на гистограмму "переплат" клиентов тарифа Смарт:

# %%
title = 'Гистограмма переплат, тариф "Смарт"'
df_filtered = df_event_numbers[(df_event_numbers['Тариф'] == 'smart') & 
                               (df_event_numbers['Плата сверх лимита, руб.'] > 0)]['Плата сверх лимита, руб.']
df_filtered.plot(kind='hist', title=title, figsize=(20,10), ec='black', bins=50)
plt.xlabel("Сумма переплат, руб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Выводы:** Большинство переплачивает до 1500 рублей. Это довольно много, учитывая, что размер абонентский платы - 550 рублей.
# Посмотрю ближе:

# %%
title = 'Гистограмма переплат, тариф "Смарт"'
df_filtered_less1000 = df_event_numbers[(df_event_numbers['Тариф'] == 'smart') & 
                                        (df_event_numbers['Плата сверх лимита, руб.'] > 0) &
                                        (df_event_numbers['Плата сверх лимита, руб.'] < 1000)]['Плата сверх лимита, руб.']
df_filtered_less1000.plot(kind='hist', title=title, ec='black',figsize=(20,10), bins=50)
plt.xlabel("Сумма, руб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %%
title = 'Гистограмма переплат, тариф "Ультра"'
df_filtered = df_event_numbers[(df_event_numbers['Тариф'] == 'ultra') & 
                               (df_event_numbers['Плата сверх лимита, руб.'] > 0)]['Плата сверх лимита, руб.']
df_filtered.plot(kind='hist', title=title, ec='black',figsize=(20,10), bins=50)
plt.xlabel("Сумма, руб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %%
title = 'Гистограмма переплат, тариф "Ультра"'
df_filtered_less1000 = df_event_numbers[(df_event_numbers['Тариф'] == 'ultra') & 
                                        (df_event_numbers['Плата сверх лимита, руб.'] > 0) &
                                        (df_event_numbers['Плата сверх лимита, руб.'] < 1500)]['Плата сверх лимита, руб.']
df_filtered_less1000.plot(kind='hist', title=title, ec='black',figsize=(20,10), bins=100)
plt.xlabel("Сумма, руб.")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# **Выводы:** Большая часть клиентов переплачивает сумму кратную 150 рублям.
#
# Посмотрю на гистограмму "переплат" клиентов тарифа Ультра:

# %%
(df_event_numbers.groupby('Тариф').sum()[['Минуты сверх', 'СМС сверх', 'Мб сверх']]).reset_index()
# Out:
#    Тариф  Минуты сверх  СМС сверх    Мб сверх
# 0  smart       92739.0      12928  6142489.54
# 1  ultra           0.0          0   738787.90

# %% [markdown]
# **Выводы:** Большое превыешение минут разговора, смс и мб. в рамках тарифа smart. В ультра только превышение трафика. Посчитаю выручку за превышение тарфых опций за каждый из тарифов.

# %%
all_revenue = df_event_numbers['Сумма за месяц, руб.'].sum()


def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} руб.)".format(pct, value)

explode = (0.1, 0)

axes = df_event_numbers.groupby('Тариф')['Сумма за месяц, руб.'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = 'Выручка', pctdistance=0.45,
                                                                     startangle=20, figsize=(20,5), colors = ['#2d6fee', '#2dcfee'],
                                                                     autopct=lambda pct: func_pct(pct))

for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.2, prop={'size':12})
    ax.set_ylabel('')

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# **Выводы:**
# 1. Исследовал данные произвел их подготовку к дальнейшему исследованию.
# 2. Написал функцию определения времени года, добавил эти данные в дата фрэйм.
# 3. Осуществил округление звонков и трафика в соответсвии с заданием, убрал нулевые значения, которые не повлияют на итоги исследования.
# 4. Построил процентное распределение пользователей по городам и построил heatmap через Folim.
# 5. Определил наиболее распространенный способ связи. Это звонки.
# 6. Больше людей пользуются тарифом Смарт.
# 7. Больше трафика проходит через тариф Смарт.
# 8. Больше отправляется смс и больше совершается звонков, и, как следствие, большую часть выручки приносит тариф Смарт, даже несмотря на что, что абонентская плата по тарифу Ультра в 3 с лишним раза выше.

# %% [markdown]
# ## Анализ данных

# %%
def plot_box(whis):
    column_list = ['Звонки, мин.', 'СМС, шт.', 'Интернет, Мб']
    rows = 1
    cols = 3
    column_list_counter = 0

    fig, axes = plt.subplots(rows, cols, figsize=(40,15))

    for r in range(rows):
        for c in range(cols):
            ax = df_event_numbers.boxplot(column=column_list[column_list_counter], by='Тариф', fontsize=40, ax=axes[c],
                                         boxprops=dict(linestyle='-', linewidth=5),
                                         medianprops=dict(linestyle='-', linewidth=5),
                                         whiskerprops=dict(linestyle='-', linewidth=5),
                                         capprops=dict(linestyle='-', linewidth=5),
                                         notch=True, whis=whis)
            ax.set_title(column_list[column_list_counter])
            ax.title.set_size(40)
            ax.set_xlabel('')
            plt.suptitle('Boxplot с whis = {}'.format(whis), y=1, fontsize=45, fontweight='bold')
            column_list_counter += 1

# %% [markdown]
# **Что сделано/что сделаю:** Сначала построю. boxplot'ы по всем рассматриваемым данным длительность звонка, количество отправленных СМС, объем использованного интернет-трафика, чтобы определить выбросы и отфильтровать их при дальнейшем анализе. Сначала зададю нижнее и верхнее значения через 2 и 98 квантили и построю один boxplot, потом построю boxplot со стандартным межквартильным размахом, равным 1,5.

# %%
plot_box([2,98])

# %%
plot_box(1.5)

# %% [markdown]
# **Что сделано/что сделаю:** При параметре whis = 1,5 аномалий отбрасывается меньше, соответственно фильтрация выполняется корректнее чем при [2,98].
# В связи с этим в дальнейшем использую интервалы данных по boxplot'ам с whis = 1,5.
# Далее напишу функцию, которая рассчитает эти интервалы:

# %%
def get_intervals(column, data_filter):
    
    if data_filter == 'Тариф':
        format_name = column
        data1, data2 = 'smart', 'ultra'
        format_end1 = 'тарифа "Смарт"'
        format_end2 = 'тарифа "Ультра"'
    elif data_filter == 'is_Moscow':
        format_name = 'is_Moscow'
        data1, data2 = 0, 1
        format_end1 = 'для регионов'
        format_end2 = 'для Москвы'
    
    q1_1 = df_event_numbers[df_event_numbers[data_filter] == data1][column].quantile(0.25)
    q3_1 = df_event_numbers[df_event_numbers[data_filter] == data1][column].quantile(0.75)
    diff_1 = q3_1 - q1_1
    
    if data_filter == 'is_Moscow':
        left_int_1 = np.where( (q1_1 - 1.5 * diff_1) > 550, q1_1 - 1.5 * diff_1, 550)
    else:
        left_int_1 = np.where( (q1_1 - 1.5 * diff_1) > 0, q1_1 - 1.5 * diff_1, 0)
    
    right_int_1 = np.where( (q3_1 + 1.5 * diff_1) > 0, q3_1 + 1.5 * diff_1, 0)
    
    q1_2 = df_event_numbers[df_event_numbers[data_filter] == data2][column].quantile(0.25)
    q3_2 = df_event_numbers[df_event_numbers[data_filter] == data2][column].quantile(0.75)
    diff_2 = q3_2 - q1_2
    
    if data_filter == 'is_Moscow':
        left_int_2 = np.where( (q1_2 - 1.5 * diff_2) > 550, q1_2 - 1.5 * diff_2, 550)
    else:
        left_int_2 = np.where( (q1_2 - 1.5 * diff_2) > 0, q1_2 - 1.5 * diff_2, 0)
        
    right_int_2 = np.where( (q3_2 + 1.5 * diff_2) > 0, q3_2 + 1.5 * diff_2, 0)
    
    print('Границы интервала для столбца "{}" {}: {} - {}'.format(column, format_end1, left_int_1, right_int_1))
    print('Границы интервала для столбца "{}" {}: {} - {}'.format(column, format_end2, left_int_2, right_int_2))
    
    return (left_int_1, right_int_1), (left_int_2, right_int_2)

# %%
calls_int_smart, calls_int_ultra = get_intervals('Звонки, мин.', 'Тариф')
# Out:
# Границы интервала для столбца "Звонки, мин." тарифа "Смарт": 0.0 - 939.5
# Границы интервала для столбца "Звонки, мин." тарифа "Ультра": 0.0 - 1454.0

# %%
sms_int_smart, sms_int_ultra = get_intervals('СМС, шт.', 'Тариф')
# Out:
# Границы интервала для столбца "СМС, шт." тарифа "Смарт": 0.0 - 112.5
# Границы интервала для столбца "СМС, шт." тарифа "Ультра": 0.0 - 188.5

# %%
internet_int_smart, internet_int_ultra = get_intervals('Интернет, Мб', 'Тариф')
# Out:
# Границы интервала для столбца "Интернет, Мб" тарифа "Смарт": 1543.129999999992 - 31142.810000000005
# Границы интервала для столбца "Интернет, Мб" тарифа "Ультра": 0.0 - 49438.83500000001

# %% [markdown]
# **Что сделано:** Определился с границами интервалов по каждому из тарифов.

# %%
def plot_hist_comparison(data):
    
    ax = plt.gca()
    func_dict = {'Звонки': 'Звонки, мин.', 'СМС': 'СМС, шт.', 'Интернет': 'Интернет, Мб'}
    xlims = [(calls_int_smart[0], calls_int_smart[1]), (calls_int_ultra[0], calls_int_ultra[1]),
             (sms_int_smart[0], sms_int_smart[1]), (sms_int_ultra[0], sms_int_ultra[1]),
             (internet_int_smart[0], internet_int_smart[1]), (internet_int_ultra[0], internet_int_ultra[1])]
    
    filt_column = func_dict[data]

    if data == 'Звонки':
        title = 'Гистограмма длительности звонков, мин.'
        xlim1 = xlims[0]
        xlim2 = xlims[1]
        text_x = (58, 8)
        text_y = 118
        count_text_x = 1150
        count_text_y = 75
        alpha = 0.8
 
    elif data == 'СМС':
        title = 'Гистограмма количества отправленных СМС, шт.'
        xlim1 = xlims[2]
        xlim2 = xlims[3]
        text_x = (5.5, 1)
        text_y = 200
        count_text_x = 148
        count_text_y = 230
        alpha = 1

    else:
        title = 'Гистограмма количества использованного интернет-трафика, Мб'
        xlim1 = xlims[4]
        xlim2 = xlims[5]
        text_x = (3300, 200)
        text_y = 130
        count_text_x = 38000
        count_text_y = 82
        alpha = 0.8
        
    
    
    filtered_smart_data = df_event_numbers[(df_event_numbers['Тариф'] == 'smart') &
                                           (df_event_numbers[filt_column] >= xlim1[0]) &
                                           (df_event_numbers[filt_column] <= xlim1[1])][filt_column]
    filtered_ultra_data = df_event_numbers[(df_event_numbers['Тариф'] == 'ultra') &
                                           (df_event_numbers[filt_column] >= xlim2[0]) &
                                           (df_event_numbers[filt_column] <= xlim2[1])][filt_column]
    
    filtered_smart_data.plot(kind='hist', bins=40, figsize=(12,6), ec='black', ax=ax, color='#2dcfee', 
                             title=title, xlim=xlim1)
    filtered_ultra_data.plot(kind='hist', bins=70, figsize=(12,6), ec='black', ax=ax, color='#2dee4c', 
                             title=title, xlim=xlim2, alpha=alpha)
    
    
    mean_smart = filtered_smart_data.mean()
    mean_ultra = filtered_ultra_data.mean()
    dispersion_smart = filtered_smart_data.var()
    dispersion_ultra = filtered_ultra_data.var()
    std_smart = filtered_smart_data.std()
    std_ultra = filtered_ultra_data.std()
    
    if data == 'СМС':
        smart_data = 'Среднее - {:.2f}\nДисперсия - {:.2f}\nstd - {:.2f}'.format(mean_smart, dispersion_smart, std_smart)
        ultra_data = 'Среднее - {:.2f}\nДисперсия - {:.2f}\nstd - {:.2f}'.format(mean_ultra, dispersion_ultra, std_ultra)
    else:
        smart_data = 'Среднее - {:.0f}\nДисперсия - {:.0f}\nstd - {:.0f}'.format(mean_smart, dispersion_smart, std_smart)
        ultra_data = 'Среднее - {:.0f}\nДисперсия - {:.0f}\nstd - {:.0f}'.format(mean_ultra, dispersion_ultra, std_ultra)
    
    legend_second = plt.legend([smart_data, ultra_data], prop={'size':10.5}, 
                                framealpha=0, bbox_to_anchor=(1.0,0.32), loc=4)
    
    
    plt.gca().add_artist(legend_second)
    
    
    plt.axvline(x=filtered_smart_data.median(),linewidth=3, color='#4c2dee', linestyle='--')
    ax.text(filtered_smart_data.median()-text_x[0], text_y, '{0:.0f}'.format(filtered_smart_data.median()), 
            fontweight='bold', fontsize='large')
    plt.axvline(x=filtered_ultra_data.median(),linewidth=3, color='#ad2dee', linestyle='--')
    ax.text(filtered_ultra_data.median()+text_x[1], text_y, '{0:.0f}'.format(filtered_ultra_data.median()), 
            fontweight='bold', fontsize='large')
    
    plt.legend(['Медиана Смарт', 'Медиана Ультра', 'Смарт', 'Ультра'], prop={'size':12})
    ax.text(count_text_x, count_text_y, 'Расчетные данные', fontweight='bold', fontsize='large')
    plt.xlabel("Сумма, руб.")
    plt.ylabel("Частота")

# %% [markdown]
# **Что сделано:** Написал функцию построения гистограммы по тарифам по длительности звонков, по количеству отправленных смс, по количеству потраченного интернет-трафика. Помимо этого, выведу  расчетные данные по среднему, дисперсии и стандартному отклонению:

# %%
plot_hist_comparison('Звонки')

# %% [markdown]
# **Выводы:** В основном, на тарифе Смарт люди разговаривают в месяц в течение 250-650 минут. Причем медиана равна 421 минуте, когда лимит общения по тарифу за абонентскую плату - 500 минут, т.е. пользователи регулярно выбирают почти полный лимит голосовой связи.
# С тарифом Ультра немного иная ситуация - большая часть пользователей вообще не разговаривает голосом. Из тех, кто разговаривает, в среднем наговаривают 524 минуты.
# По итогу, медиана тарифа Ультра больше, чем медиана Смарт.

# %%
plot_hist_comparison('СМС')

# %% [markdown]
# **Выводы:** По обоим тарифам ситуация схожая - большая часть пользователей не отправляет СМС сообщения.Однако, из тех, кто отправляет, большую активность проявляют пользователи тарифа Смарт - в среднем они отправляют до 33 СМС в месяц. Пользователи тарифа Смарт отправляют до 48 СМС.

# %%
plot_hist_comparison('Интернет')

# %% [markdown]
# **Выводы:** Клиенты с тарифом Смарт в среднем в месяц используют от 15 до 25 Гб трафика. Причем медиана равна 16,5 Гб, что вылезает за пределы абонентской платы - в 15 Гб. Фактически, клиенты тарифа Смарт регулярно заказывают доп. пакеты с интернетом, когда основной пакет заканчивается.
# Клиенты с тарифом Ультра активней пользуются интернетом - медиана равна 19 Гб, но учитывая лимит в 30 Гб, у них есть ещё большой запас трафика.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# 1. Первая гипотеза о равенстве средних двух генеральных совокупностей:
# средняя выручка пользователей тарифов Ультра</font> и Смарт различается.
#
# H0 (нулевая гипотеза) - предположение о том, что между данными у нас нет связи. В данном случае, что средняя выручка пользователей тарифа Смарт не отличается от средней выручки пользователей тарифа Ультра.
#
# H1 (альтернативная гипотеза) - средняя выручка пользователей тарифа Смарт отличается от средней выручки пользователей тарифа Ультра.

# %%
ax = df_event_numbers.boxplot(column='Сумма за месяц, руб.', by='Тариф', fontsize=12,
                                         boxprops=dict(linestyle='-', linewidth=5),
                                         medianprops=dict(linestyle='-', linewidth=5),
                                         whiskerprops=dict(linestyle='-', linewidth=5),
                                         capprops=dict(linestyle='-', linewidth=5),
                                         notch=True, figsize=(8,7))
ax.set_title('')
ax.title.set_size(40)
ax.set_xlabel('')
plt.suptitle('Boxplot по выручке с whis = 1,5', y=0.93, fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.93, 'Boxplot по выручке с whis = 1,5')

# %% [markdown]
# **Выводы:** Осуществил проверку выбросов. Далее посчитаю границы интервалов.

# %%
revenue_int_smart, revenue_int_ultra = get_intervals('Сумма за месяц, руб.', 'Тариф')
# Out:
# Границы интервала для столбца "Сумма за месяц, руб." тарифа "Смарт": 0.0 - 3550.0
# Границы интервала для столбца "Сумма за месяц, руб." тарифа "Ультра": 1950.0 - 1950.0

# %%
smart_mean_revenue = df_event_numbers[(df_event_numbers['Тариф'] == 'smart') &
                                      (df_event_numbers['Сумма за месяц, руб.'] >= revenue_int_smart[0]) &
                                      (df_event_numbers['Сумма за месяц, руб.'] <= revenue_int_smart[1])]['Сумма за месяц, руб.']

ultra_mean_revenue = df_event_numbers[(df_event_numbers['Тариф'] == 'ultra') &
                                      (df_event_numbers['Сумма за месяц, руб.'] >= revenue_int_ultra[0]) &
                                      (df_event_numbers['Сумма за месяц, руб.'] <= revenue_int_ultra[1])]['Сумма за месяц, руб.']

# %% [markdown]
# **Выводы:** Выбрал среднюю месечную выборку по тарифам смарт и ультра. Поскольку выборки у независимые, то можно воспользоваться функцией ttest_ind из модуля scipy.stats:

# %%
from scipy.stats import ttest_ind

# %%
stat, p = ttest_ind(smart_mean_revenue, ultra_mean_revenue)
print('t = {}\np-value = {:.10e}'.format(stat, p))
print('\nПороговое значение alpha = 0.05')
# Out:
# t = -28.12531985463021
# p-value = 6.1993257349e-155
#
# Пороговое значение alpha = 0.05

# %% [markdown]
# **Выводы:** Нулевая гипотеза отвергается, Верным считается утверждение, что средняя выручка пользователей тарифов Смарт и Ультра различается. Проверю, в чью пользу:

# %%
print('Средняя выручка по пользователям тарифа "Смарт" - {:.2f}'.format(smart_mean_revenue.mean()))
print('Средняя выручка по пользователям тарифа "Ультра" - {}'.format(ultra_mean_revenue.mean()))
# Out:
# Средняя выручка по пользователям тарифа "Смарт" - 1246.16
# Средняя выручка по пользователям тарифа "Ультра" - 1950.0

# %% [markdown]
# **Выводы:** Ожидаемо, что пользователи тарифа "Ультра" в среднем приносят больше денег, т.к. их абонентская плата в 3 с лишним раза выше, чем абонентская плата пользующихся тарифом Смарт (1950р. против 550р.). Клиенты с тарифом Смарт, конечно, довольно часто (в 75% случаев) "вылезают" за пределы своего тарифа и заказывают доп. услуги, но всё равно не догоняют по тратам на пользователя клиентов с тарифом Ультра.
# Далее проверю вторую гипотеза о равенстве средних двух генеральных совокупностей:
# средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Выберу нужные - среднюю месячную выручку по Москве и по остальным регионам.
# Проставим признак по каждой строке - Москва или регион.

# %%
df_event_numbers['is_Moscow'] = np.where(df_event_numbers['Город'] == 'Москва', 1, 0)

# %%
df_event_numbers.head()
# Out:
#    User_id Время года  Месяц  Кол-во звонков, шт.  Звонки, мин.  СМС, шт.  \
# 0     1000      весна      5                 22.0         159.0      22.0
# 1     1000       зима     12                 46.0         333.0      70.0
# 2     1000       лето      6                 43.0         172.0      60.0
# 3     1000       лето      7                 47.0         340.0      75.0
# 4     1000       лето      8                 52.0         408.0      81.0
#
#    Интернет, Мб  Тариф      Город    Широта  ...  Аб. плата, руб.  \
# 0       2253.49  ultra  Краснодар  45.03547  ...             1950
# 1       9817.61  ultra  Краснодар  45.03547  ...             1950
# 2      23233.77  ultra  Краснодар  45.03547  ...             1950
# 3      14003.64  ultra  Краснодар  45.03547  ...             1950
# 4      14055.93  ultra  Краснодар  45.03547  ...             1950
#
#    Интернет, Гб  Минуты сверх  СМС сверх  Мб сверх  Гб сверх  \
# ...

# %%
ax = df_event_numbers.boxplot(column='Сумма за месяц, руб.', by='is_Moscow', fontsize=12,
                                         boxprops=dict(linestyle='-', linewidth=5),
                                         medianprops=dict(linestyle='-', linewidth=5),
                                         whiskerprops=dict(linestyle='-', linewidth=5),
                                         capprops=dict(linestyle='-', linewidth=5),
                                         notch=True, figsize=(8,7))



labels = [item.get_text() for item in ax.get_xticklabels()]

labels[0] = 'Регионы'
labels[1] = 'Москва'

ax.set_xticklabels(labels)

plt.suptitle('Boxplot по выручке в Москве и регионах с whis = 1,5', y=0.95, fontsize=16, fontweight='bold')

ax.set_xlabel('')
ax.set_title('')
ax.title.set_size(40)

# %%
revenue_int_smart, revenue_int_ultra = get_intervals('Сумма за месяц, руб.', 'is_Moscow')
# Out:
# Границы интервала для столбца "Сумма за месяц, руб." для регионов: 550.0 - 3750.0
# Границы интервала для столбца "Сумма за месяц, руб." для Москвы: 550.0 - 3704.25

# %% [markdown]
# **Выводы:** Посмотрел боксплоты, расчитал границы интервалов. Далее выбиру нужные данные по Москве и регионам.

# %%
moscow_revenue = df_event_numbers[(df_event_numbers['Город'] == 'Москва') &
                                  (df_event_numbers['Сумма за месяц, руб.'] >= revenue_int_smart[0]) &
                                  (df_event_numbers['Сумма за месяц, руб.'] <= revenue_int_smart[1])]['Сумма за месяц, руб.']

regions_revenue = df_event_numbers[(df_event_numbers['Город'] != 'Москва') &
                                  (df_event_numbers['Сумма за месяц, руб.'] >= revenue_int_ultra[0]) &
                                  (df_event_numbers['Сумма за месяц, руб.'] <= revenue_int_ultra[1])]['Сумма за месяц, руб.']

# %%
stat, p = ttest_ind(moscow_revenue, regions_revenue)
print('t = {}\np-value = {:.2}'.format(stat, p))
print('\nПороговое значение alpha = 0.05')
# Out:
# t = 1.4426413860035516
# p-value = 0.15
#
# Пороговое значение alpha = 0.05

# %%
print('Средняя выручка по пользователю в месяц в Москве: {:.2f}'.format(moscow_revenue.mean()))
print('Средняя выручка по пользователю в месяц в регионах: {:.2f}'.format(regions_revenue.mean()))
# Out:
# Средняя выручка по пользователю в месяц в Москве: 1528.26
# Средняя выручка по пользователю в месяц в регионах: 1480.85

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# Нулевую гипотезу отвергнуть не получается.
# Таким образом, верно утверждение, что средняя выручка пользователей из Москвы не отличается от выручки пользователей из других регионов.
# В Москве в среднем платят на 50р. больше, чем в регионах. И правда, было бы странно, если бы эта разница оказалась статистически значимой.

# %% [markdown]
# ## Общий вывод

# %%
print('Тариф Смарт')
print()
smart_mean_internet = (df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['Интернет, Мб']/(1024 * 15)).mean()
print('Использование интернет-трафика  - {:.2%} = {:,.0f} Гб'.
      format(smart_mean_internet, smart_mean_internet * 1024 * 15))
smart_mean_calls = (df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['Звонки, мин.']/(500)).mean()
print('Использование пакета минут  - {:.2%} = {:.2f} мин'.
      format(smart_mean_calls, smart_mean_calls * 500))
smart_mean_sms = (df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['СМС, шт.']/(50)).mean()
print('Использование пакета СМС   - {:.2%} = {:.0f} шт.'.
      format(smart_mean_sms, smart_mean_sms * 50))

print()
print('Тариф Ультра')
print()
ultra_mean_internet = (df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['Интернет, Мб']/(1024 * 30)).mean()
print('Использование интернет-трафика - {:.2%} = {:,.0f} Гб'.
      format(ultra_mean_internet, ultra_mean_internet * 1024 * 30))
ultra_mean_calls = (df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['Звонки, мин.']/(3000)).mean()
print('Использование пакета минут - {:.2%} = {:.2f} мин'.
      format(ultra_mean_calls, ultra_mean_calls * 3000))
ultra_mean_sms = (df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['СМС, шт.']/(1000)).mean()
print('Использования пакета СМС - {:.2%} = {:.0f} шт.'.
      format(ultra_mean_sms, ultra_mean_sms * 1000))
# Out:
# Тариф Смарт
#
# Использование интернет-трафика  - 105.52% = 16,208 Гб
# Использование пакета минут  - 83.59% = 417.93 мин
# Использование пакета СМС   - 66.77% = 33 шт.
#
# Тариф Ультра
#
# Использование интернет-трафика - 63.38% = 19,469 Гб
# Использование пакета минут - 17.55% = 526.62 мин
# Использования пакета СМС - 4.94% = 49 шт.

# %% [markdown]
# **Тариф смарт**
# Всё наглядно выведено выше. В тарифе смарт в среднем избыток минут и смс, но интернет превышается на 1,3 ГБ.
#
# **Тариф Ультра**
# Тариф перенасыщен смс, минутами разговора - не используется даже половина лимитов. Интернет трафика тоже с избытком. До границы тарифа 30 ГБ не дотягивают около 10 Гб.

# %%
print('Тариф Смарт')
print()
smart_over_mean_internet = df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['Мб сверх'].mean()
smart_over_mean_internet_rub = np.round(smart_over_mean_internet, -3)/1000 * 200
print('Среднее превышение пакета интернет  - {:.0f} Мб на сумму - {:.0f} руб.'.
      format(smart_over_mean_internet, smart_over_mean_internet_rub))

smart_over_mean_calls = np.ceil(df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['Минуты сверх'].mean())
smart_over_mean_calls_rub = smart_over_mean_calls * 3
print('Среднее превышение пакета минут  - {:.0f} мин на сумму - {:.0f} руб.'.
      format(smart_over_mean_calls, smart_over_mean_calls_rub))

smart_over_mean_sms = np.ceil(df_event_numbers[(df_event_numbers['Тариф'] == 'smart')]['СМС сверх'].mean())
smart_over_mean_sms_rub = smart_over_mean_sms * 3
print('Среднее превышение пакета СМС  - {:.0f} шт. на сумму - {:.0f} руб.'.
      format(smart_over_mean_sms, smart_over_mean_sms_rub))

print()
print('Тариф Ультра')
print()

ultra_over_mean_internet = df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['Мб сверх'].mean()
ultra_over_mean_internet_rub = np.round(ultra_over_mean_internet, -3)/1000 * 150
print('Среднее превышение пакета интернета - {:.0f} Мб на сумму - {:.0f} руб.'.
      format(ultra_over_mean_internet, ultra_over_mean_internet_rub))

ultra_over_mean_calls = np.ceil(df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['Минуты сверх'].mean())
ultra_over_mean_calls_rub = ultra_over_mean_calls * 3
print('Среднее превышение пакета минут  - {:.0f} мин на сумму - {:.0f} руб.'.
      format(ultra_over_mean_calls, ultra_over_mean_calls_rub))

ultra_over_mean_sms = np.ceil(df_event_numbers[(df_event_numbers['Тариф'] == 'ultra')]['СМС сверх'].mean())
ultra_over_mean_sms_rub = ultra_over_mean_sms * 3
print('Среднее превышение пакета СМС  - {:.0f} шт. на сумму - {:.0f} руб.'.
      format(ultra_over_mean_sms, ultra_over_mean_sms_rub))
# Out:
# Тариф Смарт
#
# Среднее превышение пакета интернет  - 2756 Мб на сумму - 600 руб.
# Среднее превышение пакета минут  - 42 мин на сумму - 126 руб.
# Среднее превышение пакета СМС  - 6 шт. на сумму - 18 руб.
#
# Тариф Ультра
#
# Среднее превышение пакета интернета - 750 Мб на сумму - 150 руб.
# Среднее превышение пакета минут  - 0 мин на сумму - 0 руб.
# Среднее превышение пакета СМС  - 0 шт. на сумму - 0 руб.

# %% [markdown]
# **Тариф смарт**
# Самое прибыльное превышение (что и ожидаемо) это по интернету около 600 рублей.
#
# **Тариф Ультра**
# Поскольку тариф достаточно насыщенный, то превышения минимальны и только по интернету на 150 рублей в среднем.

# %%
all_revenue = df_event_numbers['Сумма за месяц, руб.'].sum()


def func_pct(pct):
    value = float(pct/100.*all_revenue)
    return "{:.2f}%\n({:,.0f} руб.)".format(pct, value)

explode = (0.1, 0) 

axes = df_event_numbers.groupby('Тариф')['Сумма за месяц, руб.'].sum().plot(kind='pie', subplots=True, fontsize=15,
                                                                     use_index=False, shadow=True, explode=explode,
                                                                     title = 'Выручка', pctdistance=0.45,
                                                                     startangle=20, figsize=(20,5),
                                                                     autopct=lambda pct: func_pct(pct))

for ax in axes:
    ax.legend(['Смарт', 'Ультра'], bbox_to_anchor=(0.87,0.87), framealpha=0.2, prop={'size':12})
    ax.set_ylabel('')
    
ax.title.set_size(40)
plt.tight_layout(pad=0)

# %% [markdown]
# Подытожил выручку
#
# **Тариф смарт**
# Дает больше половины прибыли. Взяли количеством.
#
# **Тариф Ультра**
# Несмотря на трехкратную разницу в цене тарифов прибыль в ультре около 40% от общей.

# %% [markdown]
# ### Обобщенный вывод

# %% [markdown]
# Тариф Смарт приносит около 60% всей выручки, но при этом на него приходится около 2200 пользователей. Тариф Ультра дает остальные 40%, но эту выручку генерируют менее 1000 пользователей.
# Среднему пользователю тарифа Смарт не хватает 2 Гб интернета к заложенными в абонентскую плату 15 Гб и ему приходится дозаказывать эти 2 Гб и доплачивать за них 400 рублей.
# Если рассматривать только тех пользователей Смарт, кто вылезает за лимиты по интернет-трафику, то средний размер доп. заказа интернет-трафика равен 3 Гб, за которые они платят 600 рублей.
#
# Таким образом, в тарифной сетке есть дешевый тариф Смарт за 550 рублей, где пользователю нехватает интернета и количество использованных минут разговора, есть тариф Ультра, стоимостью 1950 рублей в котором лимитов вполне достаточно.
#
# В общем и целом "Мегалайну" целесообразно выработать промежуточное решение, которое позволяло бы клиентам более комфортно (без дополнительных заказов) пользоваться услугами связи, при этом по цене являлось бы промежуточным вариантом между текущими Смарт и Ультра. Учитывая то, что средний пользователь тарифа Смарт дозаказывает 2 Гб на 400 рублей, т.е. платит в итоге около 950 рублей за месяц. Можно рассмотреть вариант создания 3 тарифа, в дополнение к текущим, под нейтральным названием, который включал бы в себя функции тарифа Смарт, но с пакетом интернет-трафика в 20 Гб и стоимостью 900-1000 рублей.
